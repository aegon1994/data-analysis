# %%
import requests
from bs4 import BeautifulSoup
url = 'https://movies.yahoo.com.tw/movie_thisweek.html'
url1='https://movies.yahoo.com.tw/movie_thisweek.html?page=2'
r = requests.get(url)
r1 = requests.get(url1)
res = r.text
res1 = r1.text
d = BeautifulSoup(r.text,'html5lib')
d1 = BeautifulSoup(r1.text,'html5lib')
names = d.find_all('div', class_ ="release_info")
names1 = d1.find_all('div', class_ ="release_info")
print("本週新片\n")
for name in names:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    etitle = name.find('div', class_="en").text.strip()
    date = name.find('div', class_="release_movie_time").text.strip()
    j = name.find('div',class_="level_name").text
    jr = name.find('div',class_="leveltext").span.text.strip()
    print(ctitle)
    print(etitle)
    print(date)
    print(j," ",jr,"\n")
    
for name in names1:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    etitle = name.find('div', class_="en").text.strip()
    date = name.find('div', class_="release_movie_time").text.strip()
    j = name.find('div',class_="level_name").text
    jr = name.find('div',class_="leveltext").span.text.strip()
    print(ctitle)
    print(etitle)
    print(date)
    print(j," ",jr,"\n")
    
urli = 'https://movies.yahoo.com.tw/movie_intheaters.html'
urli1='https://movies.yahoo.com.tw/movie_intheaters.html?page=2'
urli2='https://movies.yahoo.com.tw/movie_intheaters.html?page=3'
ri = requests.get(urli)
ri1 = requests.get(urli1)
ri2 = requests.get(urli2)

di = BeautifulSoup(ri.text,'html5lib')
di1 = BeautifulSoup(ri1.text,'html5lib')
di2= BeautifulSoup(ri2.text,'html5lib')
namesi = di.find_all('div', class_ ="release_info")
namesi1 = di1.find_all('div', class_ ="release_info")
namesi2 = di2.find_all('div', class_ ="release_info")
print("上映中\n")
for name in namesi:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    etitle = name.find('div', class_="en").text.strip()
    date = name.find('div', class_="release_movie_time").text.strip()
    j = name.find('div',class_="level_name").text
    jr = name.find('div',class_="leveltext").span.text.strip()
    print(ctitle)
    print(etitle)
    print(date)
    print(j," ",jr,"\n")
    
for name in namesi1:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    print(ctitle)
    etitle = name.find('div', class_="en").text.strip()
    print(etitle)
    date = name.find('div', class_="release_movie_time").text.strip()
    print(date)
    if ctitle == "Fishmans":
        print("\n")
        continue
    else:
        j = name.find('div',class_="level_name").text
        jr = name.find('div',class_="leveltext").span.text.strip()
        print(j," ",jr,"\n")
    
    
for name in namesi2:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    etitle = name.find('div', class_="en").text.strip()
    date = name.find('div', class_="release_movie_time").text.strip()
    j = name.find('div',class_="level_name").text
    jr = name.find('div',class_="leveltext").span.text.strip()
    print(ctitle)
    print(etitle)
    print(date)
    print(j," ",jr,"\n")
    
urlc = 'https://movies.yahoo.com.tw/movie_comingsoon.html'
urlc1='https://movies.yahoo.com.tw/movie_comingsoon.html?page=2'
urlc2='https://movies.yahoo.com.tw/movie_comingsoon.html?page=3'
rc = requests.get(urlc)
rc1 = requests.get(urlc1)
rc2 = requests.get(urlc2)
dc = BeautifulSoup(rc.text,'html5lib')
dc1 = BeautifulSoup(rc1.text,'html5lib')
dc2= BeautifulSoup(rc2.text,'html5lib')
namesc = dc.find_all('div', class_ ="release_info")
namesc1 = dc1.find_all('div', class_ ="release_info")
namesc2 = dc2.find_all('div', class_ ="release_info")
print("即將上映\n")
for name in namesc:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    etitle = name.find('div', class_="en").text.strip()
    date = name.find('div', class_="release_movie_time").text.strip()
    j = name.find('div',class_="level_name").text
    jr = name.find('div',class_="leveltext").span.text.strip()
    print(ctitle)
    print(etitle)
    print(date)
    print(j," ",jr,"\n")
    
for name in namesc1:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    print(ctitle)
    etitle = name.find('div', class_="en").text.strip()
    print(etitle)
    date = name.find('div', class_="release_movie_time").text.strip()
    print(date)
    if ctitle == "陰影下的她":
        print("\n")
        continue
    elif ctitle == "Anne的多重恐懼":
        print("\n")
        continue
    elif ctitle== "我的2年妓女生涯":
        print("\n")
        continue
    else:
        j = name.find('div',class_="level_name").text
        jr = name.find('div',class_="leveltext").span.text.strip()
        print(j," ",jr,"\n")
        
for name in namesc2:
    ctitle = name.find('div',class_="release_movie_name").a.text.strip()
    print(ctitle)
    if ctitle == "消失的紫斑蝶":
        date = name.find('div', class_="release_movie_time").text.strip()
        print(date)
        print("\n")
        continue
    etitle = name.find('div', class_="en").text.strip()
    print(etitle)
    date = name.find('div', class_="release_movie_time").text.strip()
    print(date)
    if ctitle == "烈火焚身":
        print("\n")
        continue
    elif ctitle == "色局追兇":
        print("\n")
        continue
    elif ctitle== "名偵探神助理：黃金螺旋之謎":
        print("\n")
        continue
    else:
        j = name.find('div',class_="level_name").text
        jr = name.find('div',class_="leveltext").span.text.strip()
        print(j," ",jr,"\n")
# Out:
# 本週新片
#
# 速命道
# Red Line
# 上映日期：
#                 2023-04-27
# 期待度   70%
#
# 梵蒂岡驅魔士
# The Pope’s Exorcist
# 上映日期：
#                 2023-04-28
# 期待度   90%
#
# 窄路微塵
# The Narrow Road
# 上映日期：
#                 2023-04-28
# 期待度   67%
#
# 離不開你的依賴
# Dependence
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 這就是我
# I Am What I Am
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 追兇12夜
# The Night of the 12th
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 心之谷
# Whisper of the Heart
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 絕命控制
# Control
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 愛情美樂地
# Joyland
# 上映日期：
#                 2023-04-28
# 期待度   50%
#
# 扶桑花女孩之舞
# Hula Fulla Dance
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 限時追捕
# The Blackout
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 魯蛇大翻身
# Rebound
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 危險療程
# A Dangerous Method
# 上映日期：
#                 2023-04-28
# 期待度   100%
#
# 麻罪犯
# bitters WEED
# 上映日期：
#                 2023-04-28
# 期待度   97%
#
# 上映中
#
# 愛是自私
# Egoist
# 上映日期：
#                 2023-04-21
# 期待度   89%
#
# 月之圓缺
# Phases of the Moon
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 電影刀劍亂舞-黎明-
# Touken Ranbu: The Movie 2
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 炸彈客
# The Bomber
# 上映日期：
#                 2023-04-21
# 期待度   75%
#
# 屍智症
# The Elderly
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 電影版 佐佐木與宮野 卒業篇
#
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 寶可噩夢
# Beau Is Afraid
# 上映日期：
#                 2023-04-21
# 期待度   75%
#
# 詭樓
# Lockdown Tower
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 絕地營救
# The Covenant
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 不能流淚的悲傷
# Behind The Blueeyes
# 上映日期：
#                 2023-04-21
# 期待度   75%
#
# 地中海發燒友
# Mediterranean Fever
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 阿凡達：水之道
# Avatar: The Way of Water
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 惡靈地堡
# The Bunker Game
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# 烈火亞當
# Young Adam
# 上映日期：
#                 2023-04-21
# 期待度   96%
#
# 空巢
# Alone
# 上映日期：
#                 2023-04-21
# 期待度   100%
#
# Fishmans
# Fishmans
# 上映日期：
#                 2023-04-21
#
#
# 鬼玩人：復活
# Evil Dead Rise
# 上映日期：
#                 2023-04-20
# 期待度   100%
#
# 吸血鬼特助：雷菲爾
# Renfield
# 上映日期：
#                 2023-04-14
# 期待度   95%
#
# 柴可夫斯基的妻子
# Tchaikovsky's Wife
# 上映日期：
#                 2023-04-14
# 期待度   100%
#
# 疫起
# Eye of the Storm
# 上映日期：
#                 2023-04-14
# 期待度   93%
#
# 涅槃咒
# Blood Karma
# 上映日期：
#                 2023-04-14
# 期待度   100%
#
# 正年輕
# Forever Young
# 上映日期：
#                 2023-04-14
# 期待度   67%
#
# 燈火闌珊
# A Light Never Goes Out
# 上映日期：
#                 2023-04-14
# 期待度   50%
#
# 聖母院大火：世紀浩劫
# Notre Dame on Fire
# 上映日期：
#                 2023-04-14
# 期待度   100%
#
# 穆荷蘭大道 4K數位修復版
# Mulholland Drive
# 上映日期：
#                 2023-04-14
# 期待度   100%
#
# 假面騎士劇場版
# Battle Royale
# 上映日期：
#                 2023-04-14
# 期待度   83%
#
# 厄林
# It’s In The Woods
# 上映日期：
#                 2023-04-14
# 期待度   100%
#
# 小淘氣尼古拉：快樂的源頭
# LITTLE NICHOLAS：Happy As Can Be
# 上映日期：
#                 2023-04-14
# 期待度   100%
#
# 長春事件
# Eternal Spring
# 上映日期：
#                 2023-04-07
# 期待度   80%
#
# 百花
# A Hundred Flowers
# 上映日期：
#                 2023-04-07
# 期待度   97%
#
# 即將上映
#
# 星際異攻隊3
# Guardians of the Galaxy Vol. 3
# 上映日期：
#                 2023-05-03
# 期待度   88%
#
# 王立宇宙軍～歐尼亞米斯之翼～：4K數位修復版
# ROYAL SPACE FORCE – The Wings of Honnêamise
# 上映日期：
#                 2023-05-03
# 期待度   100%
#
# 揮灑心篇章
# Maestro(s)
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 指尖上綻放的愛
# A Mother's Touch
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 追殺代理人
# Simulant
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 燃燒的玫瑰
# The Colors of Fire
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 上流謀殺案
# Invitation to a Murder
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 鬼噤聲
# Tainted Soul
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 萊拉兄弟
# Leila’s Brothers
# 上映日期：
#                 2023-05-05
# 期待度   100%
#
# 我的幸福婚約
# As Long As We Both Shall Live
# 上映日期：
#                 2023-05-12
# 期待度   100%
#
# 神鬼聖戰
# The Devil Conspiracy
# 上映日期：
#                 2023-05-12
# 期待度   100%
#
# 湯道
# Yudo
# 上映日期：
#                 2023-05-12
# 期待度   100%
#
# 油麻菜籽
# Ah Fei
# 上映日期：
#                 2023-05-12
# 期待度   80%
#
# 龍馬精神
# Ride On
# 上映日期：
#                 2023-05-12
# 期待度   65%
#
# 正宗巨齒鯊
# The Black Demon
# 上映日期：
#                 2023-05-12
# 期待度   100%
#
# 金之國水之國
# Gold Kingdom and Water Kingdom
# 上映日期：
#                 2023-05-12
# 期待度   100%
#
# 陰影下的她
# Next Sohee
# 上映日期：
#                 2023-05-12
#
#
# Anne的多重恐懼
# Faces of Anne
# 上映日期：
#                 2023-05-12
#
#
# 玫瑰母親
# Mother and Son
# 上映日期：
#                 2023-05-12
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_47392/3036355435.py in <module>
#     127         continue
#     128     else:
# --> 129         j = name.find('div',class_="level_name").text
#     130         jr = name.find('div',class_="leveltext").span.text.strip()
#     131         print(j," ",jr,"\n")
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Out:
# {'movie name': ['速命道', '梵蒂岡驅魔士', '窄路微塵', '離不開你的依賴', '這就是我', '追兇12夜', '心之谷', '絕命控制', '愛情美樂地', '扶桑花女孩之舞'], 'movie name in English': ['Red Line', 'The Pope’s Exorcist', 'The Narrow Road', 'Dependence', 'I Am What I Am', 'The Night of the 12th', 'Whisper of the Heart', 'Control', 'Joyland', 'Hula Fulla Dance'], 'date': ['上映日期：\n                2023-04-27', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28', '上映日期：\n                2023-04-28'], '期待度': ['73%', '88%', '67%', '100%', '100%', '100%', '100%', '100%', '50%', '100%']}
